# %% [markdown]
# # 데이터 불러오기/살펴보기
#
# ### 주요 내용
#
# 1. csv, xlsx 파일 불러오기
# 2. 데이터 살펴보기
# 3. DRM 보안 파일 불러오기
#
# <br>
#
# ### 목표
# 1. 분석에 필요한 데이터를 python으로 불러올 수 있다.
# 2. 데이터의 일부나 특성을 확인할 수 있다.
#
#
# <br>
# <hr>
# <br>

# %% [markdown]
# ## 1. 파일 불러와서 살펴보기
#
# **pandas** 라이브러리의 *read_csv()* 등의 함수를 활용해서 데이터 불러오기 가능
# 아래의 표현들을 활용해서 데이터 파일의 경로 지정 필요
#
# * `/` : **root**. Windows에서는 C:\
# * `~/` : 사용자 폴더. Windows에서는 C:\Users\사용자계정이름
# * `./` : 현재 작업 폴더(working directory), 별도로 작업하지 않은 경우 생략 가능
# * `../` : 현재 폴더의 상위 폴더
#
#
# `바탕화면`처럼 익숙한 곳에 새로운 폴더를 만들고, 데이터 파일을 옮겨서 작업하는 것을 추천

# %%
# 현재 작업 폴더 확인
    ## print working directory
# %pwd

# %% [markdown]
# <br>
#
# ### 1.1. CSV 파일 불러오기
#
# **pandas** 라이브러리 불러오기

# %%
import pandas as pd

# %%
# pandas의 read_csv( ) 활용
df_ins= pd.read_csv("./data/03_insurance.csv")
df_ins
    ## 경로가 중요!
    ## ./ : ipynb 노트북 파일 폴더
    ## ./ 생략 가능
# Out:
#     age     sex    bmi  children smoker     region
# 0    56  female  23.91         3     no  northeast
# 1    46  female  37.67         2    yes  northeast
# 2    32    male  21.80         2    yes  northwest
# 3    60    male  31.19         4     no  northeast
# 4    25    male  15.01         2    yes  northeast
# ..  ...     ...    ...       ...    ...        ...
# 95   24    male  19.47         3     no  southwest
# 96   26  female  24.16         4    yes  northwest
# 97   41  female  33.60         1     no  northwest
# 98   18    male  33.02         3    yes  southwest
# 99   61  female  22.70         1     no  northeast
#
# [100 rows x 6 columns]

# %%
# 타입 확인
type(df_ins)
    ## "DataFrame"
# Out:
# pandas.core.frame.DataFrame

# %%
# 메서드의 확인(마침표 뒤에서 Tab 누르기)
df_ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       100 non-null    int64
#  1   sex       100 non-null    object
#  2   bmi       100 non-null    float64
#  3   children  100 non-null    int64
#  4   smoker    100 non-null    object
#  5   region    100 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 4.8+ KB

# %% [markdown]
# <br>
#
# ### 1.2. 데이터 살펴보기

# %%
# head( )로 앞 몇개 관측치 확인
df_ins.head()
# Out:
#    age     sex    bmi  children smoker     region
# 0   56  female  23.91         3     no  northeast
# 1   46  female  37.67         2    yes  northeast
# 2   32    male  21.80         2    yes  northwest
# 3   60    male  31.19         4     no  northeast
# 4   25    male  15.01         2    yes  northeast

# %%
# tail( )로 끝 몇 개 관측치 확인
df_ins.tail(n=3)
# Out:
#     age     sex    bmi  children smoker     region
# 97   41  female  33.60         1     no  northwest
# 98   18    male  33.02         3    yes  southwest
# 99   61  female  22.70         1     no  northeast

# %%
# row / column 개수 확인
df_ins.shape
# Out:
# (100, 6)

# %%
# 관측치 개수만 확인
df_ins.shape[1]
# Out:
# 6

# %%
# index(행 이름) 확인
df_ins.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
# columns(변수 이름) 확인
df_ins.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region'], dtype='object')

# %%
# 변수 형식 확인
df_ins.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# dtype: object

# %% [markdown]
# <br>
#
# #### [실습] data 폴더의 03_PulseRates.csv를 불러와서 df_pr로 저장하기
#
# 이후 자유롭게 데이터 탐색하기

# %% [markdown]
# #### [참고] Encoding 지정 및 index, header 지정
#
# data 폴더의 03_고용지표_20221115084415.csv를 불러오기

# %%
# 인코딩(글자 저장 방법) 오류 발생
    ## UnicodeDecodeError  'utf-8' codec can't decode byte 0xbc in position 1: invalid start byte
pd.read_csv('파일 경로 작성')

# %%
# 옵션 encoding='CP949' 추가
pd.read_csv('파일 경로 작성', encoding='CP949')
# Out:
#    성별(1) 2021. 08 2021. 08.1 2021. 08.2 2021. 09 2021. 09.1 2021. 09.2  \
# 0  성별(1)  경제활동참가율        실업률        고용률  경제활동참가율        실업률        고용률
# 1     합계     61.7        4.0       59.2     61.9        3.6       59.7
# 2     남자     70.0        4.1       67.1     70.3        3.8       67.7
# 3     여자     54.2        3.9       52.1     54.3        3.4       52.5
#
#   2021. 10 2021. 10.1 2021. 10.2  ... 2022. 04.2 2022. 05 2022. 05.1  \
# 0  경제활동참가율        실업률        고용률  ...        고용률  경제활동참가율        실업률
# 1     62.1        4.2       59.5  ...       60.4     63.0        3.5
# 2     70.6        4.6       67.3  ...       68.7     71.8        3.7
# 3     54.5        3.7       52.5  ...       52.9     55.0        3.3
#
#   2022. 05.2 2022. 06 2022. 06.1 2022. 06.2 2022. 07 2022. 07.1 2022. 07.2
# 0        고용률  경제활동참가율        실업률        고용률  경제활동참가율        실업률        고용률
# 1       60.8     63.0        3.4       60.8     62.9        3.3       60.9
# 2       69.2     71.6        3.3       69.2     71.3        3.4       68.9
# 3       53.2     55.2        3.6       53.2     55.4        3.1         53
#
# [4 rows x 37 columns]

# %%
# index, header 지정
pd.read_csv('파일 경로 작성', encoding='CP949', index_col=0, header=[0,1])
# Out:
# 성별(1) 2021. 08            2021. 09            2021. 10            2021. 11  \
# 성별(1)  경제활동참가율  실업률   고용률  경제활동참가율  실업률   고용률  경제활동참가율  실업률   고용률  경제활동참가율
# 합계        61.7  4.0  59.2     61.9  3.6  59.7     62.1  4.2  59.5     62.5
# 남자        70.0  4.1  67.1     70.3  3.8  67.7     70.6  4.6  67.3     71.2
# 여자        54.2  3.9  52.1     54.3  3.4  52.5     54.5  3.7  52.5     54.6
#
# 성별(1)  ... 2022. 04 2022. 05            2022. 06            2022. 07       \
# 성별(1)  ...      고용률  경제활동참가율  실업률   고용률  경제활동참가율  실업률   고용률  경제활동참가율  실업률
# 합계     ...     60.4     63.0  3.5  60.8     63.0  3.4  60.8     62.9  3.3
# 남자     ...     68.7     71.8  3.7  69.2     71.6  3.3  69.2     71.3  3.4
# 여자     ...     52.9     55.0  3.3  53.2     55.2  3.6  53.2     55.4  3.1
#
# 성별(1)
# 성별(1)   고용률
# 합계     60.9
# 남자     68.9
# 여자     53.0
#
# [3 rows x 36 columns]

# %% [markdown]
# <br>
#
#
# ### 1.3. Excel 파일 불러오기
#
# `Excel` 파일은 구버전의 **xls**와 새로운 버전의 **xlsx**로 구분하며 추가 라이브러리 `xlrd`와 `openpyxl` 설치 필수
#  이후 pandas의 `read_excel( )`을 사용 가능
#  > pandas 1.3 이전 버전에서는 **xlsx** 파일을 불러올 때 함수 안에 `, engine='openpyxl'`를 추가해야할 수도 있습니다.
#
#  data 폴더의 03_test.xlsx 파일 불러오기

# %%
# 무난한 첫번째 시트 데이터 불러오기
sheet1 = pd.read_excel('파일 경로')
sheet1
# Out:
#    ID  Var1  Var2  Var3
# 0   1    11    45    75
# 1   2    54    32    34
# 2   4    65    43    54

# %%
# 시트 번호 지정하고 2줄 무시하기
sheet2 = pd.read_excel('파일 경로', sheet_name=1, skiprows=2)
sheet2
    ## sheet_name : 시트 이름이나 번호 지정, 번호는 0부터 시작
    ## skiprows   : 무시할 행 수
# Out:
#    이름  나이    키
# 0  민서  20  160
# 1  민준  21  175

# %%
# 첫 행부터 데이터가 시작되는 데이터 불러오기
sheet3 = pd.read_excel('파일 경로', sheet_name=2, header=None)
sheet3
    ## header : 첫 행에 변수이름이 저장되었는지 여부
# Out:
#       0   1
# 0  2015  32
# 1  2016  34
# 2  2017   -

# %%
# 첫 행부터 데이터가 시작되는 데이터 불러오면서 변수 이름 지정하기
sheet3 = pd.read_excel('파일 경로', sheet_name=2, header=None, names=['년도','건수'])
sheet3
# Out:
#      년도  건수
# 0  2015  32
# 1  2016  34
# 2  2017   -

# %%
# 결측 저장값 지정하기
sheet3 = pd.read_excel('파일 경로', sheet_name=2, header=None, names=['년도','건수'], na_values='-')
sheet3
    ## NaN : 결측값
# Out:
#      년도    건수
# 0  2015  32.0
# 1  2016  34.0
# 2  2017   NaN

# %% [markdown]
# <br>
#
# ####  [실습] 아래의 사이트에서 관심있는 데이터를 탐색하기
#
# * csv 파일 중 인코딩 관련 에러가 발생할 경우 read_csv( )안에서 `encoding='CP949'` 옵션 추가
# * xlsx의 경우 다운로드한 파일을 열어서 읽기 전용을 해제해야 할 수도 있음
#
#
#
# [공공데이터포털](https://www.data.go.kr/index.do)
#
# [서울 열린데이터 광장](http://data.seoul.go.kr/)
#
# [Dacon](https://dacon.io/)

# %% [markdown]
# #### End of script
